# %%
data = {
	"Aru": "Aru",
	"Eimi": "Eimi",
	"Haruna": "Haruna",
	"Hihumi": "Hifumi",
	"Hina": "Hina",
	"Hoshino": "Hoshino",
	"Iori": "Iori",
	"Maki": "Maki",
	"Neru": "Neru",
	"Izumi": "Izumi",
	"Shiroko": "Shiroko",
	"Shun": "Shun",
	"Sumire": "Sumire",
	"Tsurugi": "Tsurugi",
	"Akane": "Akane",
	"Chise": "Chise",
	"Akari": "Akari",
	"Hasumi": "Hasumi",
	"Nonomi": "Nonomi",
	"Kayoko": "Kayoko",
	"Mutsuki": "Mutsuki",
	"Zunko": "Junko",
	"Serika": "Serika",
	"Tsubaki": "Tsubaki",
	"Yuuka": "Yuuka",
	"Haruka": "Haruka",
	"Asuna": "Asuna",
	"Kotori": "Kotori",
	"Suzumi": "Suzumi",
	"Pina": "Pina",
	"Hibiki": "Hibiki",
	"karin": "Karin",
	"Saya": "Saya",
	"Airi": "Airi",
	"Fuuka": "Fuuka",
	"Hanae": "Hanae",
	"Hare": "Hare",
	"Utaha": "Utaha",
	"Ayane": "Ayane",
	"Chinatsu": "Chinatsu",
	"Kotama": "Kotama",
	"Juri": "Juri",
	"Serina": "Serina",
	"Shimiko": "Shimiko",
	"Yoshimi": "Yoshimi",
	"Mashiro": "Mashiro",
	"Izuna": "Izuna",
	"Shizuko": "Shizuko",
	"Aris": "Aris",
	"Midori": "Midori",
	"Momoi": "Momoi",
	"Cherino": "Cherino",
	"Nodoka": "Nodoka",
	"Yuzu": "Yuzu",
	"Azusa": "Azusa",
	"Hanako": "Hanako",
	"Koharu": "Koharu",
	"Azusa_Swimsuit": "AzusaSwimsuit",
	"Mashiro_Swimsuit": "MashiroSwimsuit",
	"Tsurugi_Swimsuit": "TsurugiSwimsuit",
	"Hihumi_Swimsuit": "HifumiSwimsuit",
	"CH0063": "HinaSwimsuit",
	"CH0064": "IoriSwimsuit",
	"Izumi_swimsuit": "IzumiSwimsuit",
	"Shiroko_RidingSuit": "ShirokoRiding",
	"CH0066": "ShunYoung",
	"Kirino": "Kirino",
	"Saya_Casual": "SayaCasual",
	"CH0101": "NeruBunny",
	"CH0100": "KarinBunny",
	"CH0098": "AsunaBunny",
	"CH0155": "Natsu",
	"Mari": "Mari",
	"CH9999": "HatsuneMiku",
	"ako": "Ako",
	"CH0164": "CherinoHotspring",
	"CH0163": "ChinatsuHotspring",
	"Tomoe": "Tomoe",
	"CH0165": "NodokaHotspring",
	"Aru_Newyear": "AruNewyear",
	"Mutsuki_Newyear": "MutsukiNewyear",
	"Serika_Newyear": "SerikaNewyear",
	"Wakamo": "Wakamo",
	"CH0141": "Fubuki",
	"CH0081": "Sena",
	"CH0160": "Chihiro",
	"Mimori": "Mimori",
	"CH0169": "Ui",
	"Hinata": "Hinata",
	"Marina": "Marina",
	"miyako": "Miyako",
	"CH0144": "Saki",
	"CH0145": "Miyu",
	"Kaede": "Kaede",
	"CH0156": "Iroha",
	"CH0113": "Michiru",
	"CH0114": "Tsukuyo",
	"Misaki": "Misaki",
	"Hiyori": "Hiyori",
	"Atsuko": "Atsuko",
	"CH0175": "WakamoSwimsuit",
	"CH0092": "NonomiSwimsuit",
	"CH0176": "AyaneSwimsuit",
	"Hoshino_Swimsuit": "HoshinoSwimsuit",
	"CH0180": "ShizukoSwimsuit",
	"CH0179": "IzunaSwimsuit",
	"CH0178": "ChiseSwimsuit",
	"Saori": "Saori",
	"Moe": "Moe",
	"Kazusa": "Kazusa",
	"CH0137": "Kokona",
	"CH0182": "UtahaCheerleader",
	"CH0095": "Noa",
	"CH0181": "HibikiCheerleader",
	"CH0099": "AkaneBunny",
	"CH0184": "YuukaTrack",
	"CH0186": "MariTrack",
	"CH0190": "HasumiTrack",
	"CH0159": "Himari",
	"Shigure": "Shigure",
	"CH0194": "SerinaChristmas",
	"CH0195": "HanaeChristmas",
	"CH0191": "HarunaNewyear",
	"CH0177": "FuukaNewyear",
	"CH0192": "JunkoNewyear",
	"CH0152": "Mine",
	"CH0069": "Mika",
	"CH0088": "Megu",
	"CH0170": "Kanna",
	"Sakurako": "Sakurako",
	"CH0187": "Toki",
	"Nagisa": "Nagisa",
	"CH0198": "Koyuki",
	"CH0086": "KayokoNewyear",
	"CH0087": "HarukaNewyear",
	"CH0107": "Kaho",
	"CH0200": "ArisMaid",
	"CH0211": "TokiBunny",
	"CH0203": "YuzuMaid",
	"CH0167": "Reisa"
}
